# %%
from pylab import plot,show,xlabel,ylabel
from numpy import array,empty,arange,linspace

# %%
def ln(r):
    z = 1/2
    for i in range(1001*j):
	    z = r*z*(1-z)
    return z

# %%
x = linspace(1,4,1000)
for j in range(1,10):
    y = ln(x)
    plot(x,y,"k.")

xlabel("r")
ylabel("x")
show()
